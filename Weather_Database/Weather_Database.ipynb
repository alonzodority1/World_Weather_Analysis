# %%
# Import the random module.
import random
# Import the NumPy module.
import numpy as np
# Import timeit.
import timeit
# Import the dependencies.
import pandas as pd
import gmaps
import requests
from citipy import citipy
from config import weather_api_key
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 760

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_weather["sys"]["country"]
# Out:
# 'MG'

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_weather_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | verkhozim
# Processing Record 2 of Set 1 | presidencia roque saenz pena
# Processing Record 3 of Set 1 | kapaa
# Processing Record 4 of Set 1 | bani walid
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | broome
# Processing Record 7 of Set 1 | torbay
# Processing Record 8 of Set 1 | new norfolk
# Processing Record 9 of Set 1 | dehloran
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | vostok
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | calbuco
# Processing Record 15 of Set 1 | mount gambier
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | puerto ayora
# Processing Record 19 of Set 1 | luohe
# Processing Record 20 of Set 1 | coihaique
# Processing Record 21 of Set 1 | bredasdorp
# Processing Record 22 of Set 1 | hithadhoo
# Processing Record 23 of Set 1 | port alfred
# Processing Record 24 of Set 1 | touros
# Processing Record 25 of Set 1 | mahebourg
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | chuy
# Processing Record 28 of Set 1 | dwarka
# Processing Record 29 of Set 1 | fortuna
# Processing Record 30 of Set 1 | yahotyn
# Processing Record 31 of Set 1 | victoria
# Processing Record 32 of Set 1 | kaberamaido
# Processing Record 33 of Set 1 | vaini
# Processing Record 34 of Set 1 | chokurdakh
# Processing Record 35 of Set 1 | east london
# Processing Record 36 of Set 1 | sitka
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | iranshahr
# Processing Record 39 of Set 1 | grand forks
# Processing Record 40 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 1 | tuatapere
# Processing Record 42 of Set 1 | norman wells
# Processing Record 43 of Set 1 | mar del plata
# Processing Record 44 of Set 1 | port moresby
# Processing Record 45 of Set 1 | vardo
# Processing Record 46 of Set 1 | severo-kurilsk
# Processing Record 47 of Set 1 | sao filipe
# Processing Record 48 of Set 1 | dikson
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | la libertad
# Processing Record 1 of Set 2 | ucluelet
# Processing Record 2 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 2 | doha
# Processing Record 4 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 2 | upernavik
# Processing Record 7 of Set 2 | santarem
# Processing Record 8 of Set 2 | sur
# Processing Record 9 of Set 2 | bambanglipuro
# Processing Record 10 of Set 2 | nanortalik
# Processing Record 11 of Set 2 | punta arenas
# Processing Record 12 of Set 2 | kaitangata
# Processing Record 13 of Set 2 | thinadhoo
# Processing Record 14 of Set 2 | nioro
# Processing Record 15 of Set 2 | cabo san lucas
# Processing Record 16 of Set 2 | hofn
# Processing Record 17 of Set 2 | yellowknife
# Processing Record 18 of Set 2 | sabzevar
# Processing Record 19 of Set 2 | amapa
# Processing Record 20 of Set 2 | oistins
# Processing Record 21 of Set 2 | bossangoa
# Processing Record 22 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 2 | butembo
# Processing Record 24 of Set 2 | vila franca do campo
# Processing Record 25 of Set 2 | adrar
# Processing Record 26 of Set 2 | shitanjing
# Processing Record 27 of Set 2 | los llanos de aridane
# Processing Record 28 of Set 2 | bethel
# Processing Record 29 of Set 2 | kenai
# Processing Record 30 of Set 2 | kholodnyy
# Processing Record 31 of Set 2 | rocha
# Processing Record 32 of Set 2 | ostrovnoy
# Processing Record 33 of Set 2 | moron
# Processing Record 34 of Set 2 | maturin
# Processing Record 35 of Set 2 | cape town
# Processing Record 36 of Set 2 | hermanus
# Processing Record 37 of Set 2 | swan hill
# Processing Record 38 of Set 2 | geresk
# City not found. Skipping...
# Processing Record 39 of Set 2 | zima
# Processing Record 40 of Set 2 | port hedland
# Processing Record 41 of Set 2 | olenegorsk
# Processing Record 42 of Set 2 | bonavista
# Processing Record 43 of Set 2 | nguru
# Processing Record 44 of Set 2 | pisco
# Processing Record 45 of Set 2 | la ronge
# Processing Record 46 of Set 2 | saskylakh
# Processing Record 47 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 2 | natal
# Processing Record 49 of Set 2 | avarua
# Processing Record 50 of Set 2 | tougan
# Processing Record 1 of Set 3 | cabo rojo
# Processing Record 2 of Set 3 | hualmay
# Processing Record 3 of Set 3 | yirol
# City not found. Skipping...
# Processing Record 4 of Set 3 | sangin
# Processing Record 5 of Set 3 | beringovskiy
# Processing Record 6 of Set 3 | egvekinot
# Processing Record 7 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 3 | santa maria
# Processing Record 9 of Set 3 | north bend
# Processing Record 10 of Set 3 | edd
# Processing Record 11 of Set 3 | hasaki
# Processing Record 12 of Set 3 | port elizabeth
# Processing Record 13 of Set 3 | kloulklubed
# Processing Record 14 of Set 3 | la rioja
# Processing Record 15 of Set 3 | eregli
# Processing Record 16 of Set 3 | noumea
# Processing Record 17 of Set 3 | luderitz
# Processing Record 18 of Set 3 | ribeira grande
# Processing Record 19 of Set 3 | pinheiro machado
# Processing Record 20 of Set 3 | cherskiy
# Processing Record 21 of Set 3 | lagoa
# Processing Record 22 of Set 3 | matamoros
# Processing Record 23 of Set 3 | hervey bay
# Processing Record 24 of Set 3 | begun
# Processing Record 25 of Set 3 | port hardy
# Processing Record 26 of Set 3 | champerico
# Processing Record 27 of Set 3 | burnie
# Processing Record 28 of Set 3 | aksarka
# Processing Record 29 of Set 3 | anopino
# Processing Record 30 of Set 3 | atig
# Processing Record 31 of Set 3 | airai
# Processing Record 32 of Set 3 | khatanga
# Processing Record 33 of Set 3 | ahipara
# Processing Record 34 of Set 3 | alingsas
# Processing Record 35 of Set 3 | alice springs
# Processing Record 36 of Set 3 | plettenberg bay
# Processing Record 37 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 3 | tobol
# Processing Record 39 of Set 3 | emerald
# Processing Record 40 of Set 3 | axim
# Processing Record 41 of Set 3 | praia
# Processing Record 42 of Set 3 | marang
# Processing Record 43 of Set 3 | cayenne
# Processing Record 44 of Set 3 | conceicao do araguaia
# Processing Record 45 of Set 3 | chakradharpur
# Processing Record 46 of Set 3 | zambezi
# Processing Record 47 of Set 3 | khash
# Processing Record 48 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 3 | nkayi
# Processing Record 50 of Set 3 | geraldton
# Processing Record 1 of Set 4 | nikolskoye
# Processing Record 2 of Set 4 | dingle
# Processing Record 3 of Set 4 | donegal
# Processing Record 4 of Set 4 | srostki
# Processing Record 5 of Set 4 | digoin
# Processing Record 6 of Set 4 | shimoda
# Processing Record 7 of Set 4 | san patricio
# Processing Record 8 of Set 4 | shiyan
# Processing Record 9 of Set 4 | longyearbyen
# Processing Record 10 of Set 4 | tuktoyaktuk
# Processing Record 11 of Set 4 | naze
# Processing Record 12 of Set 4 | mayo
# Processing Record 13 of Set 4 | arraial do cabo
# Processing Record 14 of Set 4 | kaoma
# Processing Record 15 of Set 4 | leningradskiy
# Processing Record 16 of Set 4 | vanimo
# Processing Record 17 of Set 4 | araouane
# Processing Record 18 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 20 of Set 4 | coquimbo
# Processing Record 21 of Set 4 | codrington
# Processing Record 22 of Set 4 | teya
# Processing Record 23 of Set 4 | hamilton
# Processing Record 24 of Set 4 | khandyga
# Processing Record 25 of Set 4 | aklavik
# Processing Record 26 of Set 4 | mataura
# Processing Record 27 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 4 | ilulissat
# Processing Record 29 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 4 | harper
# Processing Record 31 of Set 4 | melnikovo
# Processing Record 32 of Set 4 | ous
# Processing Record 33 of Set 4 | flin flon
# Processing Record 34 of Set 4 | baracoa
# Processing Record 35 of Set 4 | hilo
# Processing Record 36 of Set 4 | klyuchi
# Processing Record 37 of Set 4 | sinnamary
# Processing Record 38 of Set 4 | bathsheba
# Processing Record 39 of Set 4 | nizwa
# Processing Record 40 of Set 4 | great yarmouth
# Processing Record 41 of Set 4 | tecpan
# Processing Record 42 of Set 4 | denizli
# Processing Record 43 of Set 4 | sobolevo
# Processing Record 44 of Set 4 | pangai
# Processing Record 45 of Set 4 | kodiak
# Processing Record 46 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 4 | college
# Processing Record 49 of Set 4 | dunmore town
# Processing Record 50 of Set 4 | dehui
# Processing Record 1 of Set 5 | butaritari
# Processing Record 2 of Set 5 | necochea
# Processing Record 3 of Set 5 | namibe
# Processing Record 4 of Set 5 | asyut
# Processing Record 5 of Set 5 | tahta
# Processing Record 6 of Set 5 | alofi
# Processing Record 7 of Set 5 | kirkwall
# Processing Record 8 of Set 5 | atar
# Processing Record 9 of Set 5 | souris
# Processing Record 10 of Set 5 | koshurnikovo
# Processing Record 11 of Set 5 | binga
# Processing Record 12 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 5 | pontes e lacerda
# Processing Record 15 of Set 5 | tasiilaq
# Processing Record 16 of Set 5 | berlevag
# Processing Record 17 of Set 5 | pevek
# Processing Record 18 of Set 5 | bud
# Processing Record 19 of Set 5 | wakkanai
# Processing Record 20 of Set 5 | martapura
# Processing Record 21 of Set 5 | clyde river
# Processing Record 22 of Set 5 | homer
# Processing Record 23 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 24 of Set 5 | provideniya
# Processing Record 25 of Set 5 | maragogi
# Processing Record 26 of Set 5 | zabol
# Processing Record 27 of Set 5 | constitucion
# Processing Record 28 of Set 5 | seryshevo
# Processing Record 29 of Set 5 | santa isabel do rio negro
# Processing Record 30 of Set 5 | peyima
# Processing Record 31 of Set 5 | qandahar
# City not found. Skipping...
# Processing Record 32 of Set 5 | kabalo
# Processing Record 33 of Set 5 | tiksi
# Processing Record 34 of Set 5 | lorengau
# Processing Record 35 of Set 5 | lasa
# Processing Record 36 of Set 5 | faanui
# Processing Record 37 of Set 5 | victor harbor
# Processing Record 38 of Set 5 | krasnoselkup
# Processing Record 39 of Set 5 | avera
# Processing Record 40 of Set 5 | ponta delgada
# Processing Record 41 of Set 5 | dagana
# Processing Record 42 of Set 5 | georgetown
# Processing Record 43 of Set 5 | isiolo
# Processing Record 44 of Set 5 | kruisfontein
# Processing Record 45 of Set 5 | bhimunipatnam
# Processing Record 46 of Set 5 | nelson bay
# Processing Record 47 of Set 5 | asfi
# Processing Record 48 of Set 5 | derzhavinsk
# Processing Record 49 of Set 5 | requena
# Processing Record 50 of Set 5 | atocha
# Processing Record 1 of Set 6 | oktyabrskiy
# Processing Record 2 of Set 6 | thompson
# Processing Record 3 of Set 6 | camaqua
# Processing Record 4 of Set 6 | kahului
# Processing Record 5 of Set 6 | tianpeng
# Processing Record 6 of Set 6 | dombarovskiy
# Processing Record 7 of Set 6 | souillac
# Processing Record 8 of Set 6 | boa vista
# Processing Record 9 of Set 6 | narsaq
# Processing Record 10 of Set 6 | iwanai
# Processing Record 11 of Set 6 | ajdabiya
# Processing Record 12 of Set 6 | saldanha
# Processing Record 13 of Set 6 | san policarpo
# Processing Record 14 of Set 6 | tres arroyos
# Processing Record 15 of Set 6 | pelym
# Processing Record 16 of Set 6 | sola
# Processing Record 17 of Set 6 | mercedes
# Processing Record 18 of Set 6 | bitung
# Processing Record 19 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 6 | flinders
# Processing Record 21 of Set 6 | barra do garcas
# Processing Record 22 of Set 6 | bambous virieux
# Processing Record 23 of Set 6 | huercal-overa
# Processing Record 24 of Set 6 | lompoc
# Processing Record 25 of Set 6 | nakusp
# Processing Record 26 of Set 6 | bijar
# Processing Record 27 of Set 6 | makakilo city
# Processing Record 28 of Set 6 | honiara
# Processing Record 29 of Set 6 | alanya
# Processing Record 30 of Set 6 | deputatskiy
# Processing Record 31 of Set 6 | haines junction
# Processing Record 32 of Set 6 | maldonado
# Processing Record 33 of Set 6 | tessalit
# Processing Record 34 of Set 6 | kitimat
# Processing Record 35 of Set 6 | samana
# Processing Record 36 of Set 6 | kavieng
# Processing Record 37 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 38 of Set 6 | dong xoai
# Processing Record 39 of Set 6 | tahlequah
# Processing Record 40 of Set 6 | barrow
# Processing Record 41 of Set 6 | grand gaube
# Processing Record 42 of Set 6 | tabas
# Processing Record 43 of Set 6 | kerema
# Processing Record 44 of Set 6 | talara
# Processing Record 45 of Set 6 | leeton
# Processing Record 46 of Set 6 | bonthe
# Processing Record 47 of Set 6 | annau
# Processing Record 48 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 49 of Set 6 | taoudenni
# Processing Record 50 of Set 6 | bermeo
# Processing Record 1 of Set 7 | mokhotlong
# Processing Record 2 of Set 7 | shenjiamen
# Processing Record 3 of Set 7 | fukue
# Processing Record 4 of Set 7 | walvis bay
# Processing Record 5 of Set 7 | viedma
# Processing Record 6 of Set 7 | monrovia
# Processing Record 7 of Set 7 | kununurra
# Processing Record 8 of Set 7 | xiongyue
# Processing Record 9 of Set 7 | malkara
# Processing Record 10 of Set 7 | ponta do sol
# Processing Record 11 of Set 7 | ler
# Processing Record 12 of Set 7 | abu kamal
# Processing Record 13 of Set 7 | katsuura
# Processing Record 14 of Set 7 | chapayevka
# Processing Record 15 of Set 7 | voh
# Processing Record 16 of Set 7 | rokupr
# Processing Record 17 of Set 7 | charters towers
# Processing Record 18 of Set 7 | sapulpa
# Processing Record 19 of Set 7 | mullaitivu
# City not found. Skipping...
# Processing Record 20 of Set 7 | hvide sande
# Processing Record 21 of Set 7 | mombasa
# Processing Record 22 of Set 7 | ust-nera
# Processing Record 23 of Set 7 | bhadrachalam
# Processing Record 24 of Set 7 | tiarei
# Processing Record 25 of Set 7 | gogrial
# Processing Record 26 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 27 of Set 7 | van
# Processing Record 28 of Set 7 | shenzhen
# Processing Record 29 of Set 7 | mazagao
# Processing Record 30 of Set 7 | kristiansund
# Processing Record 31 of Set 7 | akdepe
# Processing Record 32 of Set 7 | khalkhal
# Processing Record 33 of Set 7 | piney green
# Processing Record 34 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 7 | jacqueville
# Processing Record 36 of Set 7 | san cristobal
# Processing Record 37 of Set 7 | lodwar
# Processing Record 38 of Set 7 | pilar
# Processing Record 39 of Set 7 | kharan
# Processing Record 40 of Set 7 | alta floresta
# Processing Record 41 of Set 7 | linxia
# Processing Record 42 of Set 7 | tual
# Processing Record 43 of Set 7 | carutapera
# Processing Record 44 of Set 7 | punta cardon
# Processing Record 45 of Set 7 | caravelas
# Processing Record 46 of Set 7 | novouzensk
# Processing Record 47 of Set 7 | lebu
# Processing Record 48 of Set 7 | saint-francois
# Processing Record 49 of Set 7 | peleduy
# Processing Record 50 of Set 7 | sokoni
# Processing Record 1 of Set 8 | laureles
# Processing Record 2 of Set 8 | zhongshu
# Processing Record 3 of Set 8 | oranjestad
# Processing Record 4 of Set 8 | pyu
# Processing Record 5 of Set 8 | vieques
# Processing Record 6 of Set 8 | santa isabel
# Processing Record 7 of Set 8 | marystown
# Processing Record 8 of Set 8 | iquitos
# Processing Record 9 of Set 8 | nikel
# Processing Record 10 of Set 8 | mitsamiouli
# Processing Record 11 of Set 8 | clinton
# Processing Record 12 of Set 8 | rawson
# Processing Record 13 of Set 8 | zhanaozen
# Processing Record 14 of Set 8 | fare
# Processing Record 15 of Set 8 | beloha
# Processing Record 16 of Set 8 | qaanaaq
# Processing Record 17 of Set 8 | saint-philippe
# Processing Record 18 of Set 8 | muroto
# Processing Record 19 of Set 8 | novyy urengoy
# Processing Record 20 of Set 8 | jiexiu
# Processing Record 21 of Set 8 | nanakuli
# Processing Record 22 of Set 8 | emba
# Processing Record 23 of Set 8 | skiros
# City not found. Skipping...
# Processing Record 24 of Set 8 | taman
# Processing Record 25 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 8 | bandarbeyla
# Processing Record 27 of Set 8 | dujuma
# City not found. Skipping...
# Processing Record 28 of Set 8 | ayolas
# Processing Record 29 of Set 8 | yar-sale
# Processing Record 30 of Set 8 | cidreira
# Processing Record 31 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 32 of Set 8 | iqaluit
# Processing Record 33 of Set 8 | ballina
# Processing Record 34 of Set 8 | prainha
# Processing Record 35 of Set 8 | hambantota
# Processing Record 36 of Set 8 | baykit
# Processing Record 37 of Set 8 | hailey
# Processing Record 38 of Set 8 | san-pedro
# Processing Record 39 of Set 8 | abha
# Processing Record 40 of Set 8 | bereda
# Processing Record 41 of Set 8 | spornoye
# Processing Record 42 of Set 8 | acajutla
# Processing Record 43 of Set 8 | kaeo
# Processing Record 44 of Set 8 | pemberton
# Processing Record 45 of Set 8 | mehamn
# Processing Record 46 of Set 8 | makat
# Processing Record 47 of Set 8 | mareeba
# Processing Record 48 of Set 8 | saint-georges
# Processing Record 49 of Set 8 | lagunas
# Processing Record 50 of Set 8 | nabire
# Processing Record 1 of Set 9 | barquisimeto
# Processing Record 2 of Set 9 | yertsevo
# Processing Record 3 of Set 9 | imeni poliny osipenko
# Processing Record 4 of Set 9 | altus
# Processing Record 5 of Set 9 | mujiayingzi
# Processing Record 6 of Set 9 | ahuimanu
# Processing Record 7 of Set 9 | mahibadhoo
# Processing Record 8 of Set 9 | brae
# Processing Record 9 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 10 of Set 9 | tiznit
# Processing Record 11 of Set 9 | goderich
# Processing Record 12 of Set 9 | sabang
# Processing Record 13 of Set 9 | port lincoln
# Processing Record 14 of Set 9 | salalah
# Processing Record 15 of Set 9 | saint-pierre
# Processing Record 16 of Set 9 | richards bay
# Processing Record 17 of Set 9 | jinchengjiang
# City not found. Skipping...
# Processing Record 18 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 9 | matara
# Processing Record 20 of Set 9 | sorland
# Processing Record 21 of Set 9 | mogadishu
# Processing Record 22 of Set 9 | manta
# Processing Record 23 of Set 9 | zheleznodorozhnyy
# Processing Record 24 of Set 9 | jacareacanga
# Processing Record 25 of Set 9 | barra patuca
# Processing Record 26 of Set 9 | joao neiva
# Processing Record 27 of Set 9 | villamontes
# Processing Record 28 of Set 9 | kieta
# Processing Record 29 of Set 9 | rosetta
# Processing Record 30 of Set 9 | acapulco
# Processing Record 31 of Set 9 | xianyang
# Processing Record 32 of Set 9 | padang
# Processing Record 33 of Set 9 | zhangye
# Processing Record 34 of Set 9 | poso
# Processing Record 35 of Set 9 | coahuayana
# Processing Record 36 of Set 9 | inhambane
# Processing Record 37 of Set 9 | nerchinsk
# Processing Record 38 of Set 9 | springville
# Processing Record 39 of Set 9 | rio cuarto
# Processing Record 40 of Set 9 | zapolyarnyy
# Processing Record 41 of Set 9 | kongolo
# Processing Record 42 of Set 9 | bosaso
# Processing Record 43 of Set 9 | likasi
# Processing Record 44 of Set 9 | tshikapa
# Processing Record 45 of Set 9 | bam
# Processing Record 46 of Set 9 | antofagasta
# Processing Record 47 of Set 9 | half moon bay
# Processing Record 48 of Set 9 | poykovskiy
# Processing Record 49 of Set 9 | kyren
# Processing Record 50 of Set 9 | luanda
# Processing Record 1 of Set 10 | taksimo
# Processing Record 2 of Set 10 | amudat
# Processing Record 3 of Set 10 | rodrigues alves
# Processing Record 4 of Set 10 | nyimba
# Processing Record 5 of Set 10 | mabaruma
# Processing Record 6 of Set 10 | mayor pablo lagerenza
# Processing Record 7 of Set 10 | acuitzio
# Processing Record 8 of Set 10 | umm kaddadah
# Processing Record 9 of Set 10 | palmares do sul
# Processing Record 10 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 11 of Set 10 | taltal
# Processing Record 12 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 10 | carnarvon
# Processing Record 14 of Set 10 | beysehir
# Processing Record 15 of Set 10 | lieksa
# Processing Record 16 of Set 10 | vung tau
# Processing Record 17 of Set 10 | abu dhabi
# Processing Record 18 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 19 of Set 10 | porto velho
# Processing Record 20 of Set 10 | xadani
# City not found. Skipping...
# Processing Record 21 of Set 10 | porto santo
# Processing Record 22 of Set 10 | lahad datu
# Processing Record 23 of Set 10 | bozoum
# Processing Record 24 of Set 10 | bandrele
# Processing Record 25 of Set 10 | tupik
# Processing Record 26 of Set 10 | lajedo
# Processing Record 27 of Set 10 | palmer
# Processing Record 28 of Set 10 | pacific grove
# Processing Record 29 of Set 10 | trelew
# Processing Record 30 of Set 10 | sibut
# Processing Record 31 of Set 10 | ferentino
# Processing Record 32 of Set 10 | te anau
# Processing Record 33 of Set 10 | rolim de moura
# City not found. Skipping...
# Processing Record 34 of Set 10 | armidale
# Processing Record 35 of Set 10 | nueva germania
# Processing Record 36 of Set 10 | komsomolskiy
# Processing Record 37 of Set 10 | cherepovets
# Processing Record 38 of Set 10 | pemangkat
# Processing Record 39 of Set 10 | la verne
# Processing Record 40 of Set 10 | porto seguro
# Processing Record 41 of Set 10 | saint george
# Processing Record 42 of Set 10 | vaitape
# Processing Record 43 of Set 10 | fairbanks
# Processing Record 44 of Set 10 | yambio
# Processing Record 45 of Set 10 | harnosand
# Processing Record 46 of Set 10 | praia da vitoria
# Processing Record 47 of Set 10 | bargarh
# Processing Record 48 of Set 10 | oranjemund
# Processing Record 49 of Set 10 | rogers
# Processing Record 50 of Set 10 | srednekolymsk
# Processing Record 1 of Set 11 | najran
# Processing Record 2 of Set 11 | misratah
# Processing Record 3 of Set 11 | hoopstad
# Processing Record 4 of Set 11 | kesan
# Processing Record 5 of Set 11 | neiafu
# Processing Record 6 of Set 11 | nouadhibou
# Processing Record 7 of Set 11 | imamoglu
# Processing Record 8 of Set 11 | bengkulu
# Processing Record 9 of Set 11 | hun
# Processing Record 10 of Set 11 | vallenar
# Processing Record 11 of Set 11 | dunedin
# Processing Record 12 of Set 11 | san jose
# Processing Record 13 of Set 11 | nago
# Processing Record 14 of Set 11 | bairiki
# Processing Record 15 of Set 11 | ancud
# Processing Record 16 of Set 11 | ulmeni
# Processing Record 17 of Set 11 | leh
# Processing Record 18 of Set 11 | qarqin
# Processing Record 19 of Set 11 | mandalgovi
# Processing Record 20 of Set 11 | coalcoman
# City not found. Skipping...
# Processing Record 21 of Set 11 | namatanai
# Processing Record 22 of Set 11 | esperance
# Processing Record 23 of Set 11 | lavrentiya
# Processing Record 24 of Set 11 | karasuyama
# Processing Record 25 of Set 11 | chunskiy
# Processing Record 26 of Set 11 | shorkot
# Processing Record 27 of Set 11 | rochegda
# Processing Record 28 of Set 11 | zhuhai
# Processing Record 29 of Set 11 | el prat de llobregat
# Processing Record 30 of Set 11 | dingli
# Processing Record 31 of Set 11 | itarema
# Processing Record 32 of Set 11 | iwaki
# Processing Record 33 of Set 11 | shirokiy
# Processing Record 34 of Set 11 | pachperwa
# Processing Record 35 of Set 11 | mount pleasant
# Processing Record 36 of Set 11 | arman
# Processing Record 37 of Set 11 | les cayes
# Processing Record 38 of Set 11 | kabugao
# Processing Record 39 of Set 11 | rio gallegos
# Processing Record 40 of Set 11 | warah
# Processing Record 41 of Set 11 | chaman
# Processing Record 42 of Set 11 | zhukovka
# Processing Record 43 of Set 11 | karagaylinskiy
# Processing Record 44 of Set 11 | kalmunai
# Processing Record 45 of Set 11 | north branch
# Processing Record 46 of Set 11 | ixtapa
# Processing Record 47 of Set 11 | yunjinghong
# City not found. Skipping...
# Processing Record 48 of Set 11 | lubumbashi
# Processing Record 49 of Set 11 | maymyo
# Processing Record 50 of Set 11 | pombia
# Processing Record 1 of Set 12 | virginia beach
# Processing Record 2 of Set 12 | launceston
# Processing Record 3 of Set 12 | soderhamn
# Processing Record 4 of Set 12 | tura
# Processing Record 5 of Set 12 | qaqortoq
# Processing Record 6 of Set 12 | hassleholm
# Processing Record 7 of Set 12 | yumen
# Processing Record 8 of Set 12 | jaisalmer
# Processing Record 9 of Set 12 | mitchell
# Processing Record 10 of Set 12 | tevaitoa
# Processing Record 11 of Set 12 | katangli
# Processing Record 12 of Set 12 | panlaitan
# Processing Record 13 of Set 12 | kyabe
# Processing Record 14 of Set 12 | sukumo
# Processing Record 15 of Set 12 | kaabong
# Processing Record 16 of Set 12 | marovoay
# Processing Record 17 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 18 of Set 12 | pimentel
# Processing Record 19 of Set 12 | sanghar
# Processing Record 20 of Set 12 | kalinovskaya
# Processing Record 21 of Set 12 | jasper
# Processing Record 22 of Set 12 | saint-esteve
# Processing Record 23 of Set 12 | siverek
# Processing Record 24 of Set 12 | hannibal
# Processing Record 25 of Set 12 | yaroslavl
# Processing Record 26 of Set 12 | valparaiso
# Processing Record 27 of Set 12 | romny
# Processing Record 28 of Set 12 | gornopravdinsk
# Processing Record 29 of Set 12 | bage
# Processing Record 30 of Set 12 | balancan
# Processing Record 31 of Set 12 | genhe
# Processing Record 32 of Set 12 | adana
# Processing Record 33 of Set 12 | jiuquan
# Processing Record 34 of Set 12 | umtata
# Processing Record 35 of Set 12 | kavaratti
# Processing Record 36 of Set 12 | ardakan
# Processing Record 37 of Set 12 | gat
# Processing Record 38 of Set 12 | aksu
# Processing Record 39 of Set 12 | redcliffe
# Processing Record 40 of Set 12 | sovetsk
# Processing Record 41 of Set 12 | alyangula
# Processing Record 42 of Set 12 | neijiang
# Processing Record 43 of Set 12 | kapuskasing
# Processing Record 44 of Set 12 | lucea
# Processing Record 45 of Set 12 | cajabamba
# Processing Record 46 of Set 12 | ziro
# Processing Record 47 of Set 12 | matir
# City not found. Skipping...
# Processing Record 48 of Set 12 | chandpur
# Processing Record 49 of Set 12 | jalu
# Processing Record 50 of Set 12 | cocorit
# Processing Record 1 of Set 13 | santa cruz
# Processing Record 2 of Set 13 | nikki
# Processing Record 3 of Set 13 | jensen beach
# Processing Record 4 of Set 13 | petersburg
# Processing Record 5 of Set 13 | mamlyutka
# Processing Record 6 of Set 13 | buraydah
# Processing Record 7 of Set 13 | sokna
# Processing Record 8 of Set 13 | oriximina
# Processing Record 9 of Set 13 | wuda
# Processing Record 10 of Set 13 | dorado
# Processing Record 11 of Set 13 | batagay-alyta
# Processing Record 12 of Set 13 | rudbar
# Processing Record 13 of Set 13 | klaksvik
# Processing Record 14 of Set 13 | poltar
# Processing Record 15 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 16 of Set 13 | havoysund
# Processing Record 17 of Set 13 | cabadiangan
# Processing Record 18 of Set 13 | jiwani
# Processing Record 19 of Set 13 | yulara
# Processing Record 20 of Set 13 | fukuma
# Processing Record 21 of Set 13 | comodoro rivadavia
# Processing Record 22 of Set 13 | batagay
# Processing Record 23 of Set 13 | ambulu
# Processing Record 24 of Set 13 | abilene
# Processing Record 25 of Set 13 | mahina
# Processing Record 26 of Set 13 | makung
# City not found. Skipping...
# Processing Record 27 of Set 13 | nome
# Processing Record 28 of Set 13 | fallon
# Processing Record 29 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 30 of Set 13 | vestmannaeyjar
# Processing Record 31 of Set 13 | hajiganj
# Processing Record 32 of Set 13 | port macquarie
# Processing Record 33 of Set 13 | suluq
# Processing Record 34 of Set 13 | manggar
# Processing Record 35 of Set 13 | fort frances
# Processing Record 36 of Set 13 | tanggu
# Processing Record 37 of Set 13 | tsaratanana
# Processing Record 38 of Set 13 | omsukchan
# Processing Record 39 of Set 13 | havelock
# Processing Record 40 of Set 13 | mananara
# Processing Record 41 of Set 13 | almaznyy
# Processing Record 42 of Set 13 | portland
# Processing Record 43 of Set 13 | dubrovytsya
# Processing Record 44 of Set 13 | lambare
# Processing Record 45 of Set 13 | port augusta
# Processing Record 46 of Set 13 | nara
# Processing Record 47 of Set 13 | broken hill
# Processing Record 48 of Set 13 | novominskaya
# Processing Record 49 of Set 13 | sibolga
# Processing Record 50 of Set 13 | kiunga
# Processing Record 1 of Set 14 | shonguy
# Processing Record 2 of Set 14 | danjiangkou
# Processing Record 3 of Set 14 | konya
# Processing Record 4 of Set 14 | elk point
# Processing Record 5 of Set 14 | grindavik
# Processing Record 6 of Set 14 | springbok
# Processing Record 7 of Set 14 | manado
# Processing Record 8 of Set 14 | jequitinhonha
# Processing Record 9 of Set 14 | zeya
# Processing Record 10 of Set 14 | olinda
# Processing Record 11 of Set 14 | sao jose da coroa grande
# Processing Record 12 of Set 14 | trinidad
# Processing Record 13 of Set 14 | erenhot
# Processing Record 14 of Set 14 | tazovskiy
# Processing Record 15 of Set 14 | marsh harbour
# Processing Record 16 of Set 14 | cajamar
# Processing Record 17 of Set 14 | maceio
# Processing Record 18 of Set 14 | ikalamavony
# Processing Record 19 of Set 14 | morgan city
# Processing Record 20 of Set 14 | port blair
# Processing Record 21 of Set 14 | odweyne
# Processing Record 22 of Set 14 | gizo
# Processing Record 23 of Set 14 | galle
# Processing Record 24 of Set 14 | lata
# Processing Record 25 of Set 14 | humaita
# Processing Record 26 of Set 14 | verkhoyansk
# Processing Record 27 of Set 14 | jalingo
# Processing Record 28 of Set 14 | guerrero negro
# Processing Record 29 of Set 14 | burgeo
# Processing Record 30 of Set 14 | santo domingo
# Processing Record 31 of Set 14 | orotukan
# Processing Record 32 of Set 14 | macapa
# Processing Record 33 of Set 14 | husavik
# Processing Record 34 of Set 14 | waverly
# Processing Record 35 of Set 14 | iquique
# Processing Record 36 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 37 of Set 14 | ternate
# Processing Record 38 of Set 14 | olga
# Processing Record 39 of Set 14 | atka
# City not found. Skipping...
# Processing Record 40 of Set 14 | takob
# City not found. Skipping...
# Processing Record 41 of Set 14 | sainte-anne
# Processing Record 42 of Set 14 | pampa
# Processing Record 43 of Set 14 | mana
# Processing Record 44 of Set 14 | ponyri
# Processing Record 45 of Set 14 | bastrop
# Processing Record 46 of Set 14 | alim
# Processing Record 47 of Set 14 | kachiry
# Processing Record 48 of Set 14 | fairmont
# Processing Record 49 of Set 14 | chateaubelair
# Processing Record 50 of Set 14 | abashiri
# Processing Record 1 of Set 15 | isangel
# Processing Record 2 of Set 15 | ormstown
# Processing Record 3 of Set 15 | quatre cocos
# Processing Record 4 of Set 15 | whitehorse
# Processing Record 5 of Set 15 | tazmalt
# Processing Record 6 of Set 15 | matinhos
# Processing Record 7 of Set 15 | northam
# Processing Record 8 of Set 15 | omboue
# Processing Record 9 of Set 15 | uwayl
# City not found. Skipping...
# Processing Record 10 of Set 15 | tanshui
# City not found. Skipping...
# Processing Record 11 of Set 15 | acacias
# Processing Record 12 of Set 15 | gornyy
# Processing Record 13 of Set 15 | miura
# Processing Record 14 of Set 15 | sinjah
# City not found. Skipping...
# Processing Record 15 of Set 15 | trat
# Processing Record 16 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 15 | mantua
# Processing Record 18 of Set 15 | lichuan
# Processing Record 19 of Set 15 | kegayli
# City not found. Skipping...
# Processing Record 20 of Set 15 | tezu
# Processing Record 21 of Set 15 | apache junction
# Processing Record 22 of Set 15 | nemuro
# Processing Record 23 of Set 15 | baculin
# Processing Record 24 of Set 15 | fort nelson
# Processing Record 25 of Set 15 | mendahara
# City not found. Skipping...
# Processing Record 26 of Set 15 | tabou
# Processing Record 27 of Set 15 | chulym
# Processing Record 28 of Set 15 | maniitsoq
# Processing Record 29 of Set 15 | candido mendes
# Processing Record 30 of Set 15 | pagudpud
# Processing Record 31 of Set 15 | altamira
# Processing Record 32 of Set 15 | mount isa
# Processing Record 33 of Set 15 | puerto escondido
# Processing Record 34 of Set 15 | qibili
# City not found. Skipping...
# Processing Record 35 of Set 15 | salekhard
# Processing Record 36 of Set 15 | moshi
# Processing Record 37 of Set 15 | payson
# Processing Record 38 of Set 15 | road town
# Processing Record 39 of Set 15 | annonay
# Processing Record 40 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 41 of Set 15 | nynashamn
# Processing Record 42 of Set 15 | fez
# Processing Record 43 of Set 15 | roma
# Processing Record 44 of Set 15 | swift current
# Processing Record 45 of Set 15 | greece
# Processing Record 46 of Set 15 | cockburn town
# Processing Record 47 of Set 15 | gigmoto
# Processing Record 48 of Set 15 | otradnyy
# Processing Record 49 of Set 15 | la paz
# Processing Record 50 of Set 15 | sao miguel do tapuio
# Processing Record 1 of Set 16 | aflu
# City not found. Skipping...
# Processing Record 2 of Set 16 | hazorasp
# Processing Record 3 of Set 16 | kerchevskiy
# Processing Record 4 of Set 16 | maloy
# Processing Record 5 of Set 16 | chapada dos guimaraes
# Processing Record 6 of Set 16 | whitefish
# Processing Record 7 of Set 16 | margate
# Processing Record 8 of Set 16 | nola
# Processing Record 9 of Set 16 | thunder bay
# Processing Record 10 of Set 16 | ambilobe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                            City Country    Lat     Lng  Max Temp  Humidity  \
# 0                     Verkhozim      RU  52.71   45.42     44.01        99
# 1  Presidencia Roque Saenz Pena      AR -26.79  -60.44     81.00        30
# 2                         Kapaa      US  22.08 -159.32     69.80        94
# 3                    Bani Walid      LY  31.76   13.99     73.17        38
# 4                     Jamestown      US  42.10  -79.24     46.99        75
# 5                        Broome      US  42.25  -75.83     46.00        31
# 6                        Torbay      CA  47.67  -52.73     39.00        55
# 7                   New Norfolk      AU -42.78  147.06     54.00        73
# 8                      Dehloran      IR  32.69   47.27     68.77        23
# 9                        Castro      BR -24.79  -50.01     65.93        61
#
#    Cloudiness  Wind Speed Weather Description                 Date
# 0         100        9.73     overcast clouds  2020-11-01 14:33:12
# 1           0        4.00           clear sky  2020-11-01 14:33:12
# 2           1        6.93           clear sky  2020-11-01 14:33:12
# 3          54        8.34       broken clouds  2020-11-01 14:33:12
# 4          90       12.75          light rain  2020-11-01 14:30:34
# 5         100        5.01     overcast clouds  2020-11-01 14:32:05
# 6          20       17.22          few clouds  2020-11-01 14:29:59
# 7          99        0.81     overcast clouds  2020-11-01 14:33:13
# 8          99        0.83     overcast clouds  2020-11-01 14:33:13
# 9          78        8.21       broken clouds  2020-11-01 14:33:13

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
index_city_df=city_data_df.set_index("City")
index_city_df
# Out:
#                              Country    Lat     Lng  Max Temp  Humidity  \
# City
# Verkhozim                         RU  52.71   45.42     44.01        99
# Presidencia Roque Saenz Pena      AR -26.79  -60.44     81.00        30
# Kapaa                             US  22.08 -159.32     69.80        94
# Bani Walid                        LY  31.76   13.99     73.17        38
# Jamestown                         US  42.10  -79.24     46.99        75
# ...                              ...    ...     ...       ...       ...
# Whitefish                         US  48.41 -114.34     28.99        92
# Margate                           GB  51.38    1.39     61.00        82
# Nola                              IT  40.92   14.53     66.20        59
# Thunder Bay                       CA  48.40  -89.32     26.60        58
# Ambilobe                          MG -13.20   49.05     77.45        71
#
#                               Cloudiness  Wind Speed Weather Description  \
# City
# Verkhozim                            100        9.73     overcast clouds
# Presidencia Roque Saenz Pena           0        4.00           clear sky
# Kapaa                                  1        6.93           clear sky
# Bani Walid                            54        8.34       broken clouds
# Jamestown                             90       12.75          light rain
# ...                                  ...         ...                 ...
# Whitefish                              1        0.76           clear sky
# Margate                               73       10.00       broken clouds
# Nola                                  75        3.36       broken clouds
# Thunder Bay                           75       21.92       broken clouds
# Ambilobe                              38        3.47          light rain
#
#                                              Date
# City
# Verkhozim                     2020-11-01 14:33:12
# Presidencia Roque Saenz Pena  2020-11-01 14:33:12
# Kapaa                         2020-11-01 14:33:12
# Bani Walid                    2020-11-01 14:33:12
# Jamestown                     2020-11-01 14:30:34
# ...                                           ...
# Whitefish                     2020-11-01 14:33:59
# Margate                       2020-11-01 14:33:59
# Nola                          2020-11-01 14:33:59
# Thunder Bay                   2020-11-01 14:29:22
# Ambilobe                      2020-11-01 14:33:59
#
# [703 rows x 9 columns]

# %%
index_city_df.loc["Whitefish"]
# Out:
# Country                                 US
# Lat                                  48.41
# Lng                                -114.34
# Max Temp                             28.99
# Humidity                                92
# Cloudiness                               1
# Wind Speed                            0.76
# Weather Description              clear sky
# Date                   2020-11-01 14:33:59
# Name: Whitefish, dtype: object
